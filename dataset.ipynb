# %%
from datasets import load_dataset
from lerobot.datasets.lerobot_dataset import LeRobotDataset

dataset = LeRobotDataset(
    repo_id="NONHUMAN-RESEARCH/TEST_RECORD_ANNOTATIONS",
    root="/home/jorge/NONHUMAN/ds/test/",
    )

print(dataset)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from datasets import load_dataset
# ----> 2 from lerobot.datasets.lerobot_dataset import LeRobotDataset
#       4 dataset = LeRobotDataset(
#       5     repo_id="NONHUMAN-RESEARCH/TEST_RECORD_ANNOTATIONS",
#       6     root="/home/jorge/NONHUMAN/ds/test/",
#       7     )
#       9 print(dataset)
#
# ModuleNotFoundError: No module named 'lerobot'

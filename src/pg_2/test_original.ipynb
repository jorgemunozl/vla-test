# %%
from transformers import (
    PaliGemmaProcessor,
    PaliGemmaForConditionalGeneration,
)
from transformers.image_utils import load_image
import torch

model_id = "jorgemunozl/pi05_ki_pg2_general_task_index"

url = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/transformers/tasks/car.jpg"
image = load_image(url)

model = PaliGemmaForConditionalGeneration.from_pretrained(model_id, torch_dtype=torch.bfloat16, device_map="auto").eval()
processor = PaliGemmaProcessor.from_pretrained(model_id)

prompt = "describe en"
model_inputs = processor(text=prompt, images=image, return_tensors="pt").to(torch.bfloat16).to(model.device)
input_len = model_inputs["input_ids"].shape[-1]

with torch.inference_mode():
    generation = model.generate(**model_inputs, max_new_tokens=100, do_sample=False)
    generation = generation[0][input_len:]
    decoded = processor.decode(generation, skip_special_tokens=True)
    print(decoded)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/9.00G [00:00<?, ?B/s]
# Loading weights: 0it [00:00, ?it/s]
# This checkpoint seem corrupted. The tied weights mapping for this model specifies to tie model.language_model.embed_tokens.weight to lm_head.weight, but both are absent from the checkpoint, and we could not find another related tied weight for those keys
# PaliGemmaForConditionalGeneration LOAD REPORT from: jorgemunozl/pi05_ki_pg2_general_task_index
# Key                                                                                                                     | Status     |
# ------------------------------------------------------------------------------------------------------------------------+------------+-
# model.paligemma_with_expert.gemma_expert.model.layers.{0...25}.mlp.gate_proj.weight                                     | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.k_proj.bias     | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.v_proj.bias     | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.layers.{0...25}.input_layernorm.weight                       | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.q_proj.weight   | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.layer_norm2.weight        | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.layers.{0...25}.post_attention_layernorm.dense.bias                      | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.layers.{0...25}.input_layernorm.dense.bias                               | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.layers.{0...25}.self_attn.k_proj.weight                                  | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.layers.{0...25}.mlp.down_proj.weight                                     | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.mlp.fc2.weight            | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.layers.{0...25}.mlp.up_proj.weight                                       | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.layer_norm1.weight        | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.layers.{0...25}.mlp.gate_proj.weight                         | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.layers.{0...25}.mlp.down_proj.weight                         | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.layers.{0...25}.post_feedforward_layernorm.weight            | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.layers.{0...25}.self_attn.o_proj.weight                      | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.layers.{0...25}.self_attn.q_proj.weight                      | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.layer_norm2.bias          | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.layers.{0...25}.self_attn.o_proj.weight                                  | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.out_proj.weight | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.layers.{0...25}.post_attention_layernorm.dense.weight                    | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.v_proj.weight   | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.out_proj.bias   | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.mlp.fc2.bias              | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.layer_norm1.bias          | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.layers.{0...25}.self_attn.q_proj.weight                                  | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.k_proj.weight   | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.layers.{0...25}.input_layernorm.dense.weight                             | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.layers.{0...25}.self_attn.v_proj.weight                                  | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.post_layernorm.weight                             | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.layers.{0...25}.self_attn.v_proj.weight                      | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.layers.{0...25}.self_attn.k_proj.weight                      | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.layers.{0...25}.post_attention_layernorm.weight              | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.q_proj.bias     | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.mlp.fc1.weight            | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.layers.{0...25}.pre_feedforward_layernorm.weight             | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.encoder.layers.{0...26}.mlp.fc1.bias              | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.position_embedding.weight              | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.layers.{0...25}.mlp.up_proj.weight                           | UNEXPECTED |
# model.action_in_proj.bias                                                                                               | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.bias                   | UNEXPECTED |
# model.action_in_proj.weight                                                                                             | UNEXPECTED |
# model.time_mlp_out.weight                                                                                               | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.multi_modal_projector.linear.weight                                         | UNEXPECTED |
# model.action_out_proj.weight                                                                                            | UNEXPECTED |
# model.time_mlp_in.bias                                                                                                  | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.embeddings.patch_embedding.weight                 | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.multi_modal_projector.linear.bias                                           | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.norm.dense.weight                                                        | UNEXPECTED |
# model.paligemma_with_expert.paligemma.lm_head.weight                                                                    | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.model.norm.dense.bias                                                          | UNEXPECTED |
# model.time_mlp_out.bias                                                                                                 | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.language_model.norm.weight                                                  | UNEXPECTED |
# model.paligemma_with_expert.gemma_expert.lm_head.weight                                                                 | UNEXPECTED |
# model.paligemma_with_expert.paligemma.model.vision_tower.vision_model.post_layernorm.bias                               | UNEXPECTED |
# model.action_out_proj.bias                                                                                              | UNEXPECTED |
# model.time_mlp_in.weight                                                                                                | UNEXPECTED |
# model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.v_proj.weight                                         | MISSING    |
# model.language_model.layers.{0...17}.self_attn.o_proj.weight                                                            | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.mlp.fc2.weight                                                  | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.k_proj.weight                                         | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.k_proj.bias                                           | MISSING    |
# model.language_model.layers.{0...17}.mlp.down_proj.weight                                                               | MISSING    |
# model.language_model.layers.{0...17}.post_attention_layernorm.weight                                                    | MISSING    |
# model.language_model.layers.{0...17}.self_attn.v_proj.weight                                                            | MISSING    |
# model.language_model.layers.{0...17}.self_attn.k_proj.weight                                                            | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.mlp.fc2.bias                                                    | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.layer_norm2.weight                                              | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.layer_norm1.weight                                              | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.mlp.fc1.bias                                                    | MISSING    |
# model.language_model.layers.{0...17}.mlp.gate_proj.weight                                                               | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.q_proj.bias                                           | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.out_proj.bias                                         | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.v_proj.bias                                           | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.mlp.fc1.weight                                                  | MISSING    |
# model.language_model.layers.{0...17}.self_attn.q_proj.weight                                                            | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.layer_norm2.bias                                                | MISSING    |
# model.vision_tower.vision_model.post_layernorm.weight                                                                   | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.q_proj.weight                                         | MISSING    |
# model.language_model.layers.{0...17}.input_layernorm.weight                                                             | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.layer_norm1.bias                                                | MISSING    |
# model.vision_tower.vision_model.encoder.layers.{0...26}.self_attn.out_proj.weight                                       | MISSING    |
# model.language_model.layers.{0...17}.mlp.up_proj.weight                                                                 | MISSING    |
# model.language_model.embed_tokens.weight                                                                                | MISSING    |
# model.vision_tower.vision_model.embeddings.position_embedding.weight                                                    | MISSING    |
# model.multi_modal_projector.linear.weight                                                                               | MISSING    |
# model.vision_tower.vision_model.embeddings.patch_embedding.weight                                                       | MISSING    |
# lm_head.weight                                                                                                          | MISSING    |
# model.vision_tower.vision_model.post_layernorm.bias                                                                     | MISSING    |
# model.vision_tower.vision_model.embeddings.patch_embedding.bias                                                         | MISSING    |
# model.language_model.norm.weight                                                                                        | MISSING    |
# model.multi_modal_projector.linear.bias                                                                                 | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 14
#      11 image = load_image(url)
#      13 model = PaliGemmaForConditionalGeneration.from_pretrained(model_id, torch_dtype=torch.bfloat16, device_map="auto").eval()
# ---> 14 processor = PaliGemmaProcessor.from_pretrained(model_id)
#      16 prompt = "describe en"
#      17 model_inputs = processor(text=prompt, images=image, return_tensors="pt").to(torch.bfloat16).to(model.device)
#
# File ~/miniconda3/envs/nh_05/lib/python3.12/site-packages/transformers/processing_utils.py:1403, in ProcessorMixin.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#    1401 # Get processor_dict first so we can use it to instantiate non-tokenizer sub-processors
#    1402 processor_dict, instantiation_kwargs = cls.get_processor_dict(pretrained_model_name_or_path, **kwargs)
# -> 1403 args = cls._get_arguments_from_pretrained(pretrained_model_name_or_path, processor_dict, **kwargs)
#    1404 return cls.from_args_and_dict(args, processor_dict, **instantiation_kwargs)
#
# File ~/miniconda3/envs/nh_05/lib/python3.12/site-packages/transformers/processing_utils.py:1524, in ProcessorMixin._get_arguments_from_pretrained(cls, pretrained_model_name_or_path, processor_dict, **kwargs)
#    1521 elif is_primary:
#    1522     # Primary non-tokenizer sub-processor: load via Auto class
#    1523     auto_processor_class = MODALITY_TO_AUTOPROCESSOR_MAPPING[sub_processor_type]
# -> 1524     sub_processor = auto_processor_class.from_pretrained(
#    1525         pretrained_model_name_or_path, subfolder=subfolder, **kwargs
#    1526     )
#    1527     args.append(sub_processor)
#    1529 elif sub_processor_type in processor_dict:
#    1530     # Additional non-tokenizer sub-processor: instantiate from config in processor_dict
#
# File ~/miniconda3/envs/nh_05/lib/python3.12/site-packages/transformers/models/auto/image_processing_auto.py:519, in AutoImageProcessor.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     516     # In case we have a config_dict, but it's not a timm config dict, we raise the initial exception,
#     517     # because only timm models have image processing in `config.json`.
#     518     if not is_timm_config_dict(config_dict):
# --> 519         raise initial_exception
#     521 image_processor_type = config_dict.get("image_processor_type", None)
#     522 image_processor_auto_map = None
#
# File ~/miniconda3/envs/nh_05/lib/python3.12/site-packages/transformers/models/auto/image_processing_auto.py:501, in AutoImageProcessor.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     498 # Load the image processor config
#     499 try:
#     500     # Main path for all transformers models and local TimmWrapper checkpoints
# --> 501     config_dict, _ = ImageProcessingMixin.get_image_processor_dict(
#     502         pretrained_model_name_or_path, image_processor_filename=image_processor_filename, **kwargs
#     503     )
#     504 except Exception as initial_exception:
#     505     # Fallback path for Hub TimmWrapper checkpoints. Timm models' image processing is saved in `config.json`
#     506     # instead of `preprocessor_config.json`. Because this is an Auto class and we don't have any information
#     507     # except the model name, the only way to check if a remote checkpoint is a timm model is to try to
#     508     # load `config.json` and if it fails with some error, we raise the initial exception.
#     509     try:
#
# File ~/miniconda3/envs/nh_05/lib/python3.12/site-packages/transformers/image_processing_base.py:334, in ImageProcessingMixin.get_image_processor_dict(cls, pretrained_model_name_or_path, **kwargs)
#     331     image_processor_dict = safe_load_json_file(resolved_image_processor_file)
#     333 if image_processor_dict is None:
# --> 334     raise OSError(
#     335         f"Can't load image processor for '{pretrained_model_name_or_path}'. If you were trying to load"
#     336         " it from 'https://huggingface.co/models', make sure you don't have a local directory with the"
#     337         f" same name. Otherwise, make sure '{pretrained_model_name_or_path}' is the correct path to a"
#     338         f" directory containing a {image_processor_filename} file"
#     339     )
#     341 if is_local:
#     342     logger.info(f"loading configuration file {resolved_image_processor_file}")
#
# OSError: Can't load image processor for 'jorgemunozl/pi05_ki_pg2_general_task_index'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'jorgemunozl/pi05_ki_pg2_general_task_index' is the correct path to a directory containing a preprocessor_config.json file
